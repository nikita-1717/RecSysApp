# %% [markdown]
# ### Подключение к базе и таблицы с юзерами и постами

# %%
# !pip3 install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.9 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9

# %%
from sqlalchemy import create_engine


engine = create_engine("postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml")

connection = engine.connect().execution_options(stream_results=True)

# %%
### Посты и топики
### С постами придется повозиться, сгенерируем эмбеддинги постов с помощью моделей из 10 занятия
import pandas as pd


posts_info = pd.read_sql(
    """SELECT * FROM public.post_text_df""",
    con=connection
)

posts_info
# Out:
#       post_id                                               text     topic
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %%
### Сделаем эмбеддинги постов с помощью моделей из 10 занятия

from transformers import AutoTokenizer
from transformers import BertModel  # https://huggingface.co/docs/transformers/model_doc/bert#transformers.BertModel
from transformers import RobertaModel  # https://huggingface.co/docs/transformers/model_doc/roberta#transformers.RobertaModel
from transformers import DistilBertModel  # https://huggingface.co/docs/transformers/model_doc/distilbert#transformers.DistilBertModel


def get_model(model_name):
    assert model_name in ['bert', 'roberta', 'distilbert']

    checkpoint_names = {
        'bert': 'bert-base-cased',  # https://huggingface.co/bert-base-cased
        'roberta': 'roberta-base',  # https://huggingface.co/roberta-base
        'distilbert': 'distilbert-base-cased'  # https://huggingface.co/distilbert-base-cased
    }

    model_classes = {
        'bert': BertModel,
        'roberta': RobertaModel,
        'distilbert': DistilBertModel
    }

    return AutoTokenizer.from_pretrained(checkpoint_names[model_name]), model_classes[model_name].from_pretrained(checkpoint_names[model_name])

# %%
tokenizer, model = get_model('distilbert')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]

# %%
### Сделаем датасет для постов

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding


class PostDataset(Dataset):
    def __init__(self, texts, tokenizer):
        super().__init__()

        self.texts = tokenizer.batch_encode_plus(
            texts,
            add_special_tokens=True,
            return_token_type_ids=False,
            return_tensors='pt',
            truncation=True,
            padding=True
        )
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        return {'input_ids': self.texts['input_ids'][idx], 'attention_mask': self.texts['attention_mask'][idx]}

    def __len__(self):
        return len(self.texts['input_ids'])


dataset = PostDataset(posts_info['text'].values.tolist(), tokenizer)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

loader = DataLoader(dataset, batch_size=32, collate_fn=data_collator, pin_memory=True, shuffle=False)

# %%
import torch
from tqdm import tqdm


@torch.inference_mode()
def get_embeddings_labels(model, loader):
    model.eval()

    total_embeddings = []

    for batch in tqdm(loader):
        batch = {key: batch[key].to(device) for key in ['attention_mask', 'input_ids']}

        embeddings = model(**batch)['last_hidden_state'][:, 0, :]

        total_embeddings.append(embeddings.cpu())

    return torch.cat(total_embeddings, dim=0)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
print(torch.cuda.get_device_name())

model = model.to(device)
# Out:
# cuda:0
# Tesla T4

# %%
embeddings = get_embeddings_labels(model, loader).numpy()

embeddings
# Out:
# 100%|██████████| 220/220 [01:54<00:00,  1.92it/s]
# array([[ 3.6315086e-01,  4.8937496e-02, -2.6408118e-01, ...,
#         -1.4159346e-01,  1.5918216e-02,  9.1982896e-05],
#        [ 2.3641640e-01, -1.5950108e-01, -3.2779828e-01, ...,
#         -2.8993604e-01,  1.1936528e-01, -1.6235473e-03],
#        [ 3.7519148e-01, -1.1394388e-01, -2.4054705e-01, ...,
#         -3.3891949e-01,  5.8694065e-02, -2.1265799e-02],
#        ...,
#        [ 3.4038273e-01,  6.6492192e-02, -1.6318429e-01, ...,
#         -8.6562753e-02,  2.0340374e-01,  3.2090571e-02],
#        [ 4.3209219e-01,  1.1091532e-02, -1.1730607e-01, ...,
#          7.5401559e-02,  1.0273975e-01,  1.5274222e-02],
#        [ 3.0427766e-01, -7.6215670e-02, -6.7758739e-02, ...,
#         -5.4348916e-02,  2.4438348e-01, -1.4148588e-02]], dtype=float32)

# %%
### Пытаемся кластеризовать тексты

from sklearn.decomposition import PCA

centered = embeddings - embeddings.mean()

pca = PCA(n_components=50)
pca_decomp = pca.fit_transform(centered)

# %%
from sklearn.cluster import KMeans

n_clusters = 15

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_decomp)

posts_info['TextCluster'] = kmeans.labels_

dists_columns = [f'DistanceToCluster_{i}' for i in range(n_clusters)]

dists_df = pd.DataFrame(
    data=kmeans.transform(pca_decomp),
    columns=dists_columns
)

dists_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    DistanceToCluster_0  DistanceToCluster_1  DistanceToCluster_2  \
# 0             3.458810             2.963289             3.465360
# 1             3.136563             2.812064             3.241974
# 2             3.136889             3.029662             3.390538
# 3             3.789935             3.240103             4.058219
# 4             2.778436             2.635969             3.236094
#
#    DistanceToCluster_3  DistanceToCluster_4  DistanceToCluster_5  \
# 0             3.375022             1.750747             3.578312
# 1             3.327378             1.715698             3.415339
# 2             3.257266             1.603104             3.487051
# 3             3.520090             2.339135             3.684767
# 4             3.037835             1.706164             3.150401
#
#    DistanceToCluster_6  DistanceToCluster_7  DistanceToCluster_8  \
# 0             2.335169             3.405469             2.192868
# 1             2.300796             3.209774             2.206903
# 2             2.368284             3.271920             3.004185
# 3             2.796755             3.682858             3.365612
# 4             1.999123             2.845040             2.903031
#
#    DistanceToCluster_9  DistanceToCluster_10  DistanceToCluster_11  \
# 0             3.720153              3.592309              3.416375
# 1             3.521416              3.287663              3.323189
# 2             3.525815              3.264584              3.346601
# 3             3.022531              3.827724              3.731809
# 4             3.282394              2.956027              2.813890
#
#    DistanceToCluster_12  DistanceToCluster_13  DistanceToCluster_14
# 0              2.820543              3.382396              3.440250
# 1              2.545826              3.368310              2.975758
# 2              2.874238              3.498285              2.966109
# 3              3.364566              3.740419              3.713830
# 4              2.132983              2.802884              2.640201

# %%
posts_info = pd.concat((posts_info, dists_df), axis=1)

# posts_info.drop(["text"], axis=1, inplace=True) # тут не дроп

posts_info
# Out:
#       post_id                                               text     topic  \
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
#       TextCluster  DistanceToCluster_0  DistanceToCluster_1  \
# 0               4             3.458810             2.963289
# 1               4             3.136563             2.812064
# 2               4             3.136889             3.029662
# 3               4             3.789935             3.240103
# 4               4             2.778436             2.635969
# ...           ...                  ...                  ...
# 7018           11             1.822080             2.824617
# 7019           11             1.844687             2.511177
# 7020           11             1.992049             2.547539
# 7021           13             1.519322             3.103188
# 7022            0             1.776719             2.984098
#
#       DistanceToCluster_2  DistanceToCluster_3  DistanceToCluster_4  \
# 0                3.465360             3.375022             1.750747
# 1                3.241974             3.327378             1.715698
# 2                3.390538             3.257266             1.603104
# 3                4.058219             3.520090             2.339135
# 4                3.236094             3.037835             1.706164
# ...                   ...                  ...                  ...
# 7018             3.396237             3.134031             2.956710
# 7019             3.382339             2.934237             2.952486
# 7020             3.462152             2.835088             3.190118
# 7021             3.408850             3.429641             3.201176
# 7022             3.605809             3.299855             3.238986
#
#       DistanceToCluster_5  DistanceToCluster_6  DistanceToCluster_7  \
# 0                3.578312             2.335169             3.405469
# 1                3.415339             2.300796             3.209774
# 2                3.487051             2.368284             3.271920
# 3                3.684767             2.796755             3.682858
# 4                3.150401             1.999123             2.845040
# ...                   ...                  ...                  ...
# 7018             3.228073             2.733013             2.047403
# 7019             2.880298             2.451138             1.811924
# 7020             2.752467             2.806575             2.208492
# 7021             3.542677             2.990951             1.891548
# 7022             3.283306             2.908958             2.134985
#
#       DistanceToCluster_8  DistanceToCluster_9  DistanceToCluster_10  \
# 0                2.192868             3.720153              3.592309
# 1                2.206903             3.521416              3.287663
# 2                3.004185             3.525815              3.264584
# 3                3.365612             3.022531              3.827724
# 4                2.903031             3.282394              2.956027
# ...                   ...                  ...                   ...
# 7018             3.339029             2.334197              2.763859
# 7019             3.176233             2.195526              2.426556
# 7020             3.391364             2.624222              2.188692
# 7021             3.430006             1.979372              3.137541
# 7022             3.552456             2.408187              2.889908
#
#       DistanceToCluster_11  DistanceToCluster_12  DistanceToCluster_13  \
# 0                 3.416375              2.820543              3.382396
# 1                 3.323189              2.545826              3.368310
# 2                 3.346601              2.874238              3.498285
# 3                 3.731809              3.364566              3.740419
# 4                 2.813890              2.132983              2.802884
# ...                    ...                   ...                   ...
# 7018              1.284147              2.346252              1.796414
# 7019              0.943134              2.244950              1.429669
# 7020              1.491789              2.461038              2.012508
# 7021              1.489069              2.322942              1.051951
# 7022              2.141026              2.689523              2.039767
#
#       DistanceToCluster_14
# 0                 3.440250
# 1                 2.975758
# 2                 2.966109
# 3                 3.713830
# 4                 2.640201
# ...                    ...
# 7018              3.051696
# 7019              3.197500
# 7020              3.155839
# 7021              3.216943
# 7022              3.245497
#
# [7023 rows x 19 columns]

# %%
### Очищаем память чтобы все влезло

model.cpu()

del model
del tokenizer

del dataset
del loader

del embeddings
del centered
del pca
del pca_decomp

# %%
import gc

gc.collect()
# Out:
# 31

# %%
posts_info.to_sql(
   "ni_gejlenko_features_lesson_10",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml",
    schema="public",
    if_exists='replace'
)
# Out:
# 23

# %%
posts_info
# Out:
#       post_id                                               text     topic  \
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
#       TextCluster  DistanceToCluster_0  DistanceToCluster_1  \
# 0               4             3.458810             2.963289
# 1               4             3.136563             2.812064
# 2               4             3.136889             3.029662
# 3               4             3.789935             3.240103
# 4               4             2.778436             2.635969
# ...           ...                  ...                  ...
# 7018           11             1.822080             2.824617
# 7019           11             1.844687             2.511177
# 7020           11             1.992049             2.547539
# 7021           13             1.519322             3.103188
# 7022            0             1.776719             2.984098
#
#       DistanceToCluster_2  DistanceToCluster_3  DistanceToCluster_4  \
# 0                3.465360             3.375022             1.750747
# 1                3.241974             3.327378             1.715698
# 2                3.390538             3.257266             1.603104
# 3                4.058219             3.520090             2.339135
# 4                3.236094             3.037835             1.706164
# ...                   ...                  ...                  ...
# 7018             3.396237             3.134031             2.956710
# 7019             3.382339             2.934237             2.952486
# 7020             3.462152             2.835088             3.190118
# 7021             3.408850             3.429641             3.201176
# 7022             3.605809             3.299855             3.238986
#
#       DistanceToCluster_5  DistanceToCluster_6  DistanceToCluster_7  \
# 0                3.578312             2.335169             3.405469
# 1                3.415339             2.300796             3.209774
# 2                3.487051             2.368284             3.271920
# 3                3.684767             2.796755             3.682858
# 4                3.150401             1.999123             2.845040
# ...                   ...                  ...                  ...
# 7018             3.228073             2.733013             2.047403
# 7019             2.880298             2.451138             1.811924
# 7020             2.752467             2.806575             2.208492
# 7021             3.542677             2.990951             1.891548
# 7022             3.283306             2.908958             2.134985
#
#       DistanceToCluster_8  DistanceToCluster_9  DistanceToCluster_10  \
# 0                2.192868             3.720153              3.592309
# 1                2.206903             3.521416              3.287663
# 2                3.004185             3.525815              3.264584
# 3                3.365612             3.022531              3.827724
# 4                2.903031             3.282394              2.956027
# ...                   ...                  ...                   ...
# 7018             3.339029             2.334197              2.763859
# 7019             3.176233             2.195526              2.426556
# 7020             3.391364             2.624222              2.188692
# 7021             3.430006             1.979372              3.137541
# 7022             3.552456             2.408187              2.889908
#
#       DistanceToCluster_11  DistanceToCluster_12  DistanceToCluster_13  \
# 0                 3.416375              2.820543              3.382396
# 1                 3.323189              2.545826              3.368310
# 2                 3.346601              2.874238              3.498285
# 3                 3.731809              3.364566              3.740419
# 4                 2.813890              2.132983              2.802884
# ...                    ...                   ...                   ...
# 7018              1.284147              2.346252              1.796414
# 7019              0.943134              2.244950              1.429669
# 7020              1.491789              2.461038              2.012508
# 7021              1.489069              2.322942              1.051951
# 7022              2.141026              2.689523              2.039767
#
#       DistanceToCluster_14
# 0                 3.440250
# 1                 2.975758
# 2                 2.966109
# 3                 3.713830
# 4                 2.640201
# ...                    ...
# 7018              3.051696
# 7019              3.197500
# 7020              3.155839
# 7021              3.216943
# 7022              3.245497
#
# [7023 rows x 19 columns]

# %%
posts_info.drop(["text"], axis=1, inplace=True)

# %% [markdown]
# ## Теперь приступаем к обработке действий

# %%
### Попробуем забрать, скажем, 9 миллионов, сразу очистим и оставим только view


feed_data = pd.read_sql(
    """
    SELECT
        cast(extract(hour from timestamp) as int) as hour,
        cast(extract(month from timestamp) as int) as month,
        post_id,
        gender,
        age,
        country,
        city,
        exp_group,
        os,
        source,
        target
    FROM public.feed_data JOIN public.user_data ON public.feed_data.user_id = public.user_data.user_id
    WHERE action = 'view'
    LIMIT 9000000
    """,
    con=connection
)

feed_data.head()
# Out:
#    hour  month  post_id  gender  age country       city  exp_group       os  \
# 0    17     10     5626       0   47  Russia  Sertolovo          3  Android
# 1    17     10      291       0   47  Russia  Sertolovo          3  Android
# 2    17     10     4763       0   47  Russia  Sertolovo          3  Android
# 3    17     10     3555       0   47  Russia  Sertolovo          3  Android
# 4    17     10      566       0   47  Russia  Sertolovo          3  Android
#
#   source  target
# 0    ads       1
# 1    ads       0
# 2    ads       0
# 3    ads       0
# 4    ads       0

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
from catboost import CatBoostClassifier, Pool
from tqdm import tqdm


object_cols = [
    'topic', 'TextCluster', 'gender', 'country',
    'city', 'exp_group', 'hour', 'month',
    'os', 'source'
]


catboost = CatBoostClassifier(
    iterations=200,
    learning_rate=1,
    depth=2,
    random_seed=1,
    thread_count=-1,
    task_type="GPU"
)



feed_data = pd.merge(
    feed_data,
    posts_info,
    on='post_id',
    how='left'
)

feed_data.drop(['post_id'], axis=1, inplace=True)
(feed_data.drop(['target'], axis=1)).head(10)
catboost.fit(X=feed_data.drop(['target'], axis=1), y=feed_data['target'], cat_features=object_cols)

catboost.save_model(
    'catboost_model.cbm',
    format="cbm"
)
# Out:
# 0:	learn: 0.3626632	total: 570ms	remaining: 1m 53s
# 1:	learn: 0.3553796	total: 1.06s	remaining: 1m 45s
# 2:	learn: 0.3546347	total: 1.48s	remaining: 1m 37s
# 3:	learn: 0.3539194	total: 1.96s	remaining: 1m 36s
# 4:	learn: 0.3536752	total: 2.41s	remaining: 1m 34s
# 5:	learn: 0.3534425	total: 2.87s	remaining: 1m 32s
# 6:	learn: 0.3532526	total: 3.42s	remaining: 1m 34s
# 7:	learn: 0.3531251	total: 3.86s	remaining: 1m 32s
# 8:	learn: 0.3530458	total: 4.21s	remaining: 1m 29s
# 9:	learn: 0.3518822	total: 4.53s	remaining: 1m 26s
# 10:	learn: 0.3518442	total: 4.94s	remaining: 1m 24s
# 11:	learn: 0.3511708	total: 5.27s	remaining: 1m 22s
# 12:	learn: 0.3510856	total: 5.62s	remaining: 1m 20s
# 13:	learn: 0.3510086	total: 6.08s	remaining: 1m 20s
# 14:	learn: 0.3507628	total: 6.54s	remaining: 1m 20s
# 15:	learn: 0.3506665	total: 6.99s	remaining: 1m 20s
# 16:	learn: 0.3505962	total: 7.33s	remaining: 1m 18s
# 17:	learn: 0.3501225	total: 7.65s	remaining: 1m 17s
# 18:	learn: 0.3497566	total: 7.96s	remaining: 1m 15s
# 19:	learn: 0.3496894	total: 8.29s	remaining: 1m 14s
# 20:	learn: 0.3494884	total: 8.63s	remaining: 1m 13s
# 21:	learn: 0.3494211	total: 8.95s	remaining: 1m 12s
# 22:	learn: 0.3493606	total: 9.27s	remaining: 1m 11s
# 23:	learn: 0.3493185	total: 9.67s	remaining: 1m 10s
# 24:	learn: 0.3492627	total: 9.96s	remaining: 1m 9s
# 25:	learn: 0.3491867	total: 10.3s	remaining: 1m 8s
# 26:	learn: 0.3490776	total: 10.6s	remaining: 1m 8s
# 27:	learn: 0.3488709	total: 11s	remaining: 1m 7s
# 28:	learn: 0.3488565	total: 11.3s	remaining: 1m 6s
# 29:	learn: 0.3488301	total: 11.6s	remaining: 1m 6s
# 30:	learn: 0.3487684	total: 12s	remaining: 1m 5s
# 31:	learn: 0.3486143	total: 12.3s	remaining: 1m 4s
# 32:	learn: 0.3485713	total: 12.8s	remaining: 1m 4s
# 33:	learn: 0.3485556	total: 13.3s	remaining: 1m 4s
# 34:	learn: 0.3485377	total: 13.7s	remaining: 1m 4s
# 35:	learn: 0.3485188	total: 14.2s	remaining: 1m 4s
# 36:	learn: 0.3485004	total: 15.1s	remaining: 1m 6s
# 37:	learn: 0.3484792	total: 15.7s	remaining: 1m 7s
# 38:	learn: 0.3484639	total: 16.6s	remaining: 1m 8s
# 39:	learn: 0.3483962	total: 17.4s	remaining: 1m 9s
# 40:	learn: 0.3483232	total: 17.9s	remaining: 1m 9s
# 41:	learn: 0.3482895	total: 18.4s	remaining: 1m 9s
# 42:	learn: 0.3482327	total: 19s	remaining: 1m 9s
# 43:	learn: 0.3479682	total: 19.4s	remaining: 1m 8s
# 44:	learn: 0.3479447	total: 19.8s	remaining: 1m 8s
# 45:	learn: 0.3479340	total: 20.1s	remaining: 1m 7s
# 46:	learn: 0.3479209	total: 20.4s	remaining: 1m 6s
# 47:	learn: 0.3479128	total: 20.7s	remaining: 1m 5s
# 48:	learn: 0.3479073	total: 21s	remaining: 1m 4s
# 49:	learn: 0.3478896	total: 21.4s	remaining: 1m 4s
# 50:	learn: 0.3478663	total: 21.7s	remaining: 1m 3s
# 51:	learn: 0.3478310	total: 22s	remaining: 1m 2s
# 52:	learn: 0.3478211	total: 22.3s	remaining: 1m 1s
# 53:	learn: 0.3478109	total: 22.7s	remaining: 1m 1s
# 54:	learn: 0.3477966	total: 23s	remaining: 1m
# 55:	learn: 0.3477839	total: 23.4s	remaining: 1m
# 56:	learn: 0.3477506	total: 23.7s	remaining: 59.5s
# 57:	learn: 0.3477363	total: 24s	remaining: 58.8s
# 58:	learn: 0.3476974	total: 24.4s	remaining: 58.2s
# 59:	learn: 0.3476629	total: 24.7s	remaining: 57.6s
# 60:	learn: 0.3475497	total: 25s	remaining: 56.9s
# 61:	learn: 0.3475083	total: 25.3s	remaining: 56.3s
# 62:	learn: 0.3474931	total: 25.6s	remaining: 55.8s
# 63:	learn: 0.3474862	total: 26s	remaining: 55.2s
# 64:	learn: 0.3474814	total: 26.4s	remaining: 54.7s
# 65:	learn: 0.3474546	total: 26.7s	remaining: 54.1s
# 66:	learn: 0.3474412	total: 27s	remaining: 53.6s
# 67:	learn: 0.3474341	total: 27.4s	remaining: 53.2s
# 68:	learn: 0.3474178	total: 27.7s	remaining: 52.6s
# 69:	learn: 0.3473988	total: 28.2s	remaining: 52.3s
# 70:	learn: 0.3473773	total: 28.5s	remaining: 51.8s
# 71:	learn: 0.3473730	total: 28.9s	remaining: 51.3s
# 72:	learn: 0.3473689	total: 29.2s	remaining: 50.9s
# 73:	learn: 0.3473460	total: 29.6s	remaining: 50.4s
# 74:	learn: 0.3473372	total: 30s	remaining: 50s
# 75:	learn: 0.3473266	total: 30.4s	remaining: 49.6s
# 76:	learn: 0.3473091	total: 30.8s	remaining: 49.3s
# 77:	learn: 0.3473056	total: 31.3s	remaining: 48.9s
# 78:	learn: 0.3472979	total: 31.6s	remaining: 48.4s
# 79:	learn: 0.3472888	total: 31.9s	remaining: 47.9s
# 80:	learn: 0.3472682	total: 32.5s	remaining: 47.7s
# 81:	learn: 0.3472212	total: 33.1s	remaining: 47.6s
# 82:	learn: 0.3472162	total: 33.4s	remaining: 47s
# 83:	learn: 0.3471970	total: 33.7s	remaining: 46.5s
# 84:	learn: 0.3471873	total: 34s	remaining: 46.1s
# 85:	learn: 0.3471710	total: 34.4s	remaining: 45.6s
# 86:	learn: 0.3471613	total: 34.7s	remaining: 45.1s
# 87:	learn: 0.3471566	total: 35s	remaining: 44.6s
# 88:	learn: 0.3471234	total: 35.3s	remaining: 44s
# 89:	learn: 0.3471171	total: 35.6s	remaining: 43.5s
# 90:	learn: 0.3470789	total: 36s	remaining: 43.1s
# 91:	learn: 0.3470747	total: 36.3s	remaining: 42.6s
# 92:	learn: 0.3470675	total: 36.6s	remaining: 42.1s
# 93:	learn: 0.3470589	total: 37s	remaining: 41.8s
# 94:	learn: 0.3470554	total: 37.3s	remaining: 41.3s
# 95:	learn: 0.3470493	total: 37.7s	remaining: 40.8s
# 96:	learn: 0.3470441	total: 38s	remaining: 40.3s
# 97:	learn: 0.3470391	total: 38.3s	remaining: 39.9s
# 98:	learn: 0.3470355	total: 38.6s	remaining: 39.4s
# 99:	learn: 0.3470238	total: 39s	remaining: 39s
# 100:	learn: 0.3470143	total: 39.6s	remaining: 38.9s
# 101:	learn: 0.3469994	total: 40.1s	remaining: 38.5s
# 102:	learn: 0.3469908	total: 40.4s	remaining: 38.1s
# 103:	learn: 0.3469857	total: 40.7s	remaining: 37.6s
# 104:	learn: 0.3469781	total: 41.1s	remaining: 37.2s
# 105:	learn: 0.3469706	total: 41.5s	remaining: 36.8s
# 106:	learn: 0.3469697	total: 41.9s	remaining: 36.4s
# 107:	learn: 0.3469511	total: 42.2s	remaining: 35.9s
# 108:	learn: 0.3469465	total: 42.5s	remaining: 35.5s
# 109:	learn: 0.3469305	total: 42.9s	remaining: 35.1s
# 110:	learn: 0.3469247	total: 43.3s	remaining: 34.7s
# 111:	learn: 0.3469226	total: 43.7s	remaining: 34.4s
# 112:	learn: 0.3469165	total: 44.2s	remaining: 34s
# 113:	learn: 0.3469028	total: 44.5s	remaining: 33.5s
# 114:	learn: 0.3468939	total: 44.8s	remaining: 33.1s
# 115:	learn: 0.3468888	total: 45.1s	remaining: 32.7s
# 116:	learn: 0.3468823	total: 45.4s	remaining: 32.2s
# 117:	learn: 0.3468766	total: 45.7s	remaining: 31.8s
# 118:	learn: 0.3468717	total: 46.1s	remaining: 31.4s
# 119:	learn: 0.3468406	total: 46.5s	remaining: 31s
# 120:	learn: 0.3468331	total: 46.8s	remaining: 30.6s
# 121:	learn: 0.3468252	total: 47.1s	remaining: 30.1s
# 122:	learn: 0.3468055	total: 47.5s	remaining: 29.7s
# 123:	learn: 0.3467941	total: 47.9s	remaining: 29.3s
# 124:	learn: 0.3467885	total: 48.2s	remaining: 28.9s
# 125:	learn: 0.3467801	total: 48.7s	remaining: 28.6s
# 126:	learn: 0.3467753	total: 49.1s	remaining: 28.2s
# 127:	learn: 0.3467516	total: 49.6s	remaining: 27.9s
# 128:	learn: 0.3467389	total: 50.3s	remaining: 27.7s
# 129:	learn: 0.3467337	total: 50.7s	remaining: 27.3s
# 130:	learn: 0.3467281	total: 51s	remaining: 26.9s
# 131:	learn: 0.3467047	total: 51.4s	remaining: 26.5s
# 132:	learn: 0.3467027	total: 51.7s	remaining: 26s
# 133:	learn: 0.3466967	total: 52s	remaining: 25.6s
# 134:	learn: 0.3466904	total: 52.3s	remaining: 25.2s
# 135:	learn: 0.3466670	total: 52.6s	remaining: 24.8s
# 136:	learn: 0.3466653	total: 53.1s	remaining: 24.4s
# 137:	learn: 0.3466629	total: 53.4s	remaining: 24s
# 138:	learn: 0.3466599	total: 53.9s	remaining: 23.6s
# 139:	learn: 0.3466566	total: 54.3s	remaining: 23.3s
# 140:	learn: 0.3466459	total: 54.6s	remaining: 22.9s
# 141:	learn: 0.3466277	total: 55s	remaining: 22.5s
# 142:	learn: 0.3466260	total: 55.3s	remaining: 22s
# 143:	learn: 0.3466226	total: 55.7s	remaining: 21.7s
# 144:	learn: 0.3466108	total: 56s	remaining: 21.3s
# 145:	learn: 0.3466043	total: 56.4s	remaining: 20.8s
# 146:	learn: 0.3466004	total: 56.7s	remaining: 20.4s
# 147:	learn: 0.3465989	total: 57.1s	remaining: 20.1s
# 148:	learn: 0.3465939	total: 57.5s	remaining: 19.7s
# 149:	learn: 0.3465872	total: 57.8s	remaining: 19.3s
# 150:	learn: 0.3465781	total: 58.1s	remaining: 18.9s
# 151:	learn: 0.3465735	total: 58.4s	remaining: 18.4s
# 152:	learn: 0.3465688	total: 58.7s	remaining: 18s
# 153:	learn: 0.3465494	total: 59.1s	remaining: 17.6s
# 154:	learn: 0.3465426	total: 59.4s	remaining: 17.2s
# 155:	learn: 0.3465399	total: 59.7s	remaining: 16.8s
# 156:	learn: 0.3465347	total: 1m	remaining: 16.4s
# 157:	learn: 0.3465286	total: 1m	remaining: 16s
# 158:	learn: 0.3465191	total: 1m	remaining: 15.6s
# 159:	learn: 0.3465157	total: 1m 1s	remaining: 15.3s
# 160:	learn: 0.3465082	total: 1m 1s	remaining: 14.9s
# 161:	learn: 0.3465062	total: 1m 1s	remaining: 14.5s
# 162:	learn: 0.3465005	total: 1m 2s	remaining: 14.1s
# 163:	learn: 0.3464966	total: 1m 2s	remaining: 13.7s
# 164:	learn: 0.3464907	total: 1m 2s	remaining: 13.3s
# 165:	learn: 0.3464852	total: 1m 3s	remaining: 13s
# 166:	learn: 0.3464716	total: 1m 3s	remaining: 12.6s
# 167:	learn: 0.3464575	total: 1m 3s	remaining: 12.2s
# 168:	learn: 0.3463645	total: 1m 4s	remaining: 11.8s
# 169:	learn: 0.3463316	total: 1m 4s	remaining: 11.4s
# 170:	learn: 0.3463045	total: 1m 4s	remaining: 11s
# 171:	learn: 0.3463015	total: 1m 5s	remaining: 10.6s
# 172:	learn: 0.3463002	total: 1m 5s	remaining: 10.3s
# 173:	learn: 0.3462951	total: 1m 6s	remaining: 9.88s
# 174:	learn: 0.3462894	total: 1m 6s	remaining: 9.49s
# 175:	learn: 0.3462841	total: 1m 6s	remaining: 9.1s
# 176:	learn: 0.3462797	total: 1m 7s	remaining: 8.72s
# 177:	learn: 0.3462759	total: 1m 7s	remaining: 8.34s
# 178:	learn: 0.3462692	total: 1m 7s	remaining: 7.95s
# 179:	learn: 0.3462622	total: 1m 8s	remaining: 7.58s
# 180:	learn: 0.3462577	total: 1m 8s	remaining: 7.2s
# 181:	learn: 0.3462275	total: 1m 8s	remaining: 6.82s
# 182:	learn: 0.3462243	total: 1m 9s	remaining: 6.44s
# 183:	learn: 0.3462172	total: 1m 9s	remaining: 6.07s
# 184:	learn: 0.3462139	total: 1m 10s	remaining: 5.69s
# 185:	learn: 0.3462100	total: 1m 10s	remaining: 5.31s
# 186:	learn: 0.3461985	total: 1m 10s	remaining: 4.93s
# 187:	learn: 0.3461957	total: 1m 11s	remaining: 4.55s
# 188:	learn: 0.3461918	total: 1m 11s	remaining: 4.17s
# 189:	learn: 0.3461304	total: 1m 11s	remaining: 3.79s
# 190:	learn: 0.3460702	total: 1m 12s	remaining: 3.4s
# 191:	learn: 0.3460368	total: 1m 12s	remaining: 3.02s
# 192:	learn: 0.3460227	total: 1m 12s	remaining: 2.64s
# 193:	learn: 0.3460136	total: 1m 13s	remaining: 2.26s
# 194:	learn: 0.3459991	total: 1m 13s	remaining: 1.89s
# 195:	learn: 0.3459930	total: 1m 13s	remaining: 1.51s
# 196:	learn: 0.3459702	total: 1m 14s	remaining: 1.13s
# 197:	learn: 0.3459630	total: 1m 14s	remaining: 753ms
# 198:	learn: 0.3459509	total: 1m 14s	remaining: 376ms
# 199:	learn: 0.3459394	total: 1m 15s	remaining: 0us

# %%
feed_data
# Out:
#          hour  month  gender  age     country       city  exp_group       os  \
# 0          17     10       0   47      Russia  Sertolovo          3  Android
# 1          17     10       0   47      Russia  Sertolovo          3  Android
# 2          17     10       0   47      Russia  Sertolovo          3  Android
# 3          17     10       0   47      Russia  Sertolovo          3  Android
# 4          17     10       0   47      Russia  Sertolovo          3  Android
# ...       ...    ...     ...  ...         ...        ...        ...      ...
# 8999995    22     12       0   21  Kazakhstan       Oral          1      iOS
# 8999996    22     12       0   21  Kazakhstan       Oral          1      iOS
# 8999997    22     12       0   21  Kazakhstan       Oral          1      iOS
# 8999998    22     12       0   21  Kazakhstan       Oral          1      iOS
# 8999999    22     12       0   21  Kazakhstan       Oral          1      iOS
#
#         source  target  ... DistanceToCluster_5  DistanceToCluster_6  \
# 0          ads       1  ...            3.860138             3.272841
# 1          ads       0  ...            3.099987             2.050451
# 2          ads       0  ...            3.471943             2.898117
# 3          ads       0  ...            1.763509             2.817748
# 4          ads       0  ...            3.415749             2.679895
# ...        ...     ...  ...                 ...                  ...
# 8999995    ads       1  ...            1.368015             2.574509
# 8999996    ads       0  ...            2.620805             2.839337
# 8999997    ads       1  ...            3.286490             2.419375
# 8999998    ads       0  ...            3.305393             2.833243
# 8999999    ads       1  ...            1.928605             3.003198
#
#          DistanceToCluster_7  DistanceToCluster_8  DistanceToCluster_9  \
# 0                   2.581432             3.537853             2.886677
# 1                   2.944569             2.964678             3.391891
# 2                   2.221586             3.372871             1.655314
# 3                   3.284706             3.654030             3.528029
# 4                   2.908731             2.949802             3.167190
# ...                      ...                  ...                  ...
# 8999995             3.212251             3.311365             3.454627
# 8999996             3.344961             3.233713             3.534772
# 8999997             2.211200             3.028851             2.333081
# 8999998             2.214466             2.788526             2.510244
# 8999999             2.962526             3.609338             2.982028
#
#          DistanceToCluster_10  DistanceToCluster_11  DistanceToCluster_12  \
# 0                    3.444062              2.369195              2.573258
# 1                    2.896214              2.920964              2.275890
# 2                    3.260842              1.673599              2.591796
# 3                    2.139560              3.040757              3.344353
# 4                    3.206538              2.910431              1.656600
# ...                       ...                   ...                   ...
# 8999995              1.300154              2.882003              3.002241
# 8999996              2.552278              2.940665              3.285650
# 8999997              2.850811              1.966166              2.351593
# 8999998              2.813609              1.713249              2.157911
# 8999999              1.498634              2.439824              3.009754
#
#          DistanceToCluster_13  DistanceToCluster_14
# 0                    2.103636              3.235611
# 1                    2.976871              2.625300
# 2                    1.434709              3.575933
# 3                    3.180565              3.543414
# 4                    2.827333              2.916756
# ...                       ...                   ...
# 8999995              3.158912              3.403504
# 8999996              3.103384              3.702713
# 8999997              2.108798              3.003045
# 8999998              1.916965              2.960479
# 8999999              2.713530              3.291020
#
# [9000000 rows x 27 columns]

# %%
# feed_data.to_csv('check.csv')
